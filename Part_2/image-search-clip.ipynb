# %% [markdown]
# # Image Search Based on a Natural Language Query Using CLIP Model
#
# In this notebook, we implement a simople image search solution based on a natural language query using the CLIP model [1]. We use CLIP to pre-calculate embeddigns for images in a collection. For a given query, we calculate its embedding using CLIP and then search for the nearest neighbors in the collection of image embeddigns.
#
# The implementation is based on [2].
#
# ### References
#   1. https://openai.com/blog/clip/#rf33
#   2. https://github.com/haltakov/natural-language-image-search
#
# ### Data
# We use a small image collection available in the `tensorhouse-data` repository (`tensor-house-data/search/unspash-small`).

# %% [markdown]
# ## Load the CLIP Model

# %%
from PIL import Image

# %%
import clip
import torch
import math
import numpy as np
import pandas as pd

from PIL import Image
import shutil
import os

import matplotlib.pyplot as plt
plt.rcParams.update({'pdf.fonttype': 'truetype'})
from mpl_toolkits.axes_grid1 import ImageGrid

# %% [markdown]
# ## Load CLIP Model

# %%
#
# Load the open CLIP model
#
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# %% [markdown]
# ## Process Input Images and Save Features

# %%
from pathlib import Path

# Set the path to the images
images_path = Path(r'D:\Projects\ADM Assg 5\Assignment-5--Team-5\new_dataset')

# List all JPGs in the folder
images_files = list(images_path.glob('*.jpg'))

# Print some statistics
print(f'Images found: {len(images_files)}')

# Display images
rows, columns = (4, 4)
fig = plt.figure(figsize=(10, 10))
grid = ImageGrid(fig, 111,  
                 nrows_ncols=(rows, columns),  
                 axes_pad=0.1,  
                 )

for ax, im in zip(grid, images_files[:rows*columns]):
    ax.imshow(Image.open(im))
    ax.axis('off')
plt.show()
# Out:
# Images found: 12852

# %%
#
# Path where the feature vectors will be stored
#
features_path = Path(".") / "features"
if os.path.exists(features_path):
    shutil.rmtree(features_path)
os.makedirs(features_path)

# Function that computes the feature vectors for a batch of images
def compute_clip_features(images_batch):
    # Load all the images from the files
    images = [Image.open(image_file) for image_file in images_batch]
    
    # Preprocess all images
    images_preprocessed = torch.stack([preprocess(image) for image in images]).to(device)

    with torch.no_grad():
        # Encode the images batch to compute the feature vectors and normalize them
        images_features = model.encode_image(images_preprocessed)
        images_features /= images_features.norm(dim=-1, keepdim=True)

    # Transfer the feature vectors back to the CPU and convert to numpy
    return images_features.cpu().numpy()

# Define the batch size
batch_size = 16


# Compute how many batches are needed
batches = math.ceil(len(images_files) / batch_size)

#
# Process each batch
#
for i in range(batches):
    print(f"Processing batch {i+1}/{batches}")

    batch_ids_path = features_path / f"{i:010d}.csv"
    batch_features_path = features_path / f"{i:010d}.npy"
    
    # Only do the processing if the batch wasn't processed yet
    if not batch_features_path.exists():
        try:
            # Select the images for the current batch
            batch_files = images_files[i*batch_size : (i+1)*batch_size]

            # Compute the features and save to a numpy file
            batch_features = compute_clip_features(batch_files)
            np.save(batch_features_path, batch_features)

            # Save the image IDs to a CSV file
            image_ids = [image_file.name.split(".")[0] for image_file in batch_files]
            image_ids_data = pd.DataFrame(image_ids, columns=['image_id'])
            image_ids_data.to_csv(batch_ids_path, index=False)
        except Exception as e:
            # Catch problems with the processing to make the process more robust
            print(f'Problem with batch {i} {e}')
# Out:
# Processing batch 1/804
# Processing batch 2/804
# Processing batch 3/804
# Processing batch 4/804
# Processing batch 5/804
# Processing batch 6/804
# Processing batch 7/804
# Processing batch 8/804
# Processing batch 9/804
# Processing batch 10/804
# Processing batch 11/804
# Processing batch 12/804
# Processing batch 13/804
# Processing batch 14/804
# Processing batch 15/804
# Processing batch 16/804
# Processing batch 17/804
# Processing batch 18/804
# Processing batch 19/804
# Processing batch 20/804
# Processing batch 21/804
# Processing batch 22/804
# Processing batch 23/804
# Processing batch 24/804
# Processing batch 25/804
# Processing batch 26/804
# Processing batch 27/804
# Processing batch 28/804
# Processing batch 29/804
# Processing batch 30/804
# Processing batch 31/804
# Processing batch 32/804
# Processing batch 33/804
# Processing batch 34/804
# Processing batch 35/804
# Processing batch 36/804
# Processing batch 37/804
# Processing batch 38/804
# Processing batch 39/804
# Processing batch 40/804
# Processing batch 41/804
# Processing batch 42/804
# Processing batch 43/804
# Processing batch 44/804
# Processing batch 45/804
# Processing batch 46/804
# Processing batch 47/804
# Processing batch 48/804
# Processing batch 49/804
# Processing batch 50/804
# Processing batch 51/804
# Processing batch 52/804
# Processing batch 53/804
# Processing batch 54/804
# Processing batch 55/804
# Processing batch 56/804
# Processing batch 57/804
# Processing batch 58/804
# Processing batch 59/804
# Processing batch 60/804
# Processing batch 61/804
# Processing batch 62/804
# Processing batch 63/804
# Processing batch 64/804
# Processing batch 65/804
# Processing batch 66/804
# Processing batch 67/804
# Processing batch 68/804
# Processing batch 69/804
# Processing batch 70/804
# Processing batch 71/804
# Processing batch 72/804
# Processing batch 73/804
# Processing batch 74/804
# Processing batch 75/804
# Processing batch 76/804
# Processing batch 77/804
# Processing batch 78/804
# Processing batch 79/804
# Processing batch 80/804
# Processing batch 81/804
# Processing batch 82/804
# Processing batch 83/804
# Processing batch 84/804
# Processing batch 85/804
# Processing batch 86/804
# Processing batch 87/804
# Processing batch 88/804
# Processing batch 89/804
# Processing batch 90/804
# Processing batch 91/804
# Processing batch 92/804
# Processing batch 93/804
# Processing batch 94/804
# Processing batch 95/804
# Processing batch 96/804
# Processing batch 97/804
# Processing batch 98/804
# Processing batch 99/804
# Processing batch 100/804
# Processing batch 101/804
# Processing batch 102/804
# Processing batch 103/804
# Processing batch 104/804
# Processing batch 105/804
# Processing batch 106/804
# Processing batch 107/804
# Processing batch 108/804
# Processing batch 109/804
# Processing batch 110/804
# Processing batch 111/804
# Processing batch 112/804
# Processing batch 113/804
# Processing batch 114/804
# Processing batch 115/804
# Processing batch 116/804
# Processing batch 117/804
# Processing batch 118/804
# Processing batch 119/804
# Processing batch 120/804
# Processing batch 121/804
# Processing batch 122/804
# Processing batch 123/804
# Processing batch 124/804
# Processing batch 125/804
# Processing batch 126/804
# Processing batch 127/804
# Processing batch 128/804
# Processing batch 129/804
# Processing batch 130/804
# Processing batch 131/804
# Processing batch 132/804
# Processing batch 133/804
# Processing batch 134/804
# Processing batch 135/804
# Processing batch 136/804
# Processing batch 137/804
# Processing batch 138/804
# Processing batch 139/804
# Processing batch 140/804
# Processing batch 141/804
# Processing batch 142/804
# Processing batch 143/804
# Processing batch 144/804
# Processing batch 145/804
# Processing batch 146/804
# Processing batch 147/804
# Processing batch 148/804
# Processing batch 149/804
# Processing batch 150/804
# Processing batch 151/804
# Processing batch 152/804
# Processing batch 153/804
# Processing batch 154/804
# Processing batch 155/804
# Processing batch 156/804
# Processing batch 157/804
# Processing batch 158/804
# Processing batch 159/804
# Processing batch 160/804
# Processing batch 161/804
# Processing batch 162/804
# Processing batch 163/804
# Processing batch 164/804
# Processing batch 165/804
# Processing batch 166/804
# Processing batch 167/804
# Processing batch 168/804
# Processing batch 169/804
# Processing batch 170/804
# Processing batch 171/804
# Processing batch 172/804
# Processing batch 173/804
# Processing batch 174/804
# Processing batch 175/804
# Processing batch 176/804
# Processing batch 177/804
# Processing batch 178/804
# Processing batch 179/804
# Processing batch 180/804
# Processing batch 181/804
# Processing batch 182/804
# Processing batch 183/804
# Processing batch 184/804
# Processing batch 185/804
# Processing batch 186/804
# Processing batch 187/804
# Processing batch 188/804
# Processing batch 189/804
# Processing batch 190/804
# Processing batch 191/804
# Processing batch 192/804
# Processing batch 193/804
# Processing batch 194/804
# Processing batch 195/804
# Processing batch 196/804
# Processing batch 197/804
# Processing batch 198/804
# Processing batch 199/804
# Processing batch 200/804
# Processing batch 201/804
# Processing batch 202/804
# Processing batch 203/804
# Processing batch 204/804
# Processing batch 205/804
# Processing batch 206/804
# Processing batch 207/804
# Processing batch 208/804
# Processing batch 209/804
# Processing batch 210/804
# Processing batch 211/804
# Processing batch 212/804
# Processing batch 213/804
# Processing batch 214/804
# Processing batch 215/804
# Processing batch 216/804
# Processing batch 217/804
# Processing batch 218/804
# Processing batch 219/804
# Processing batch 220/804
# Processing batch 221/804
# Processing batch 222/804
# Processing batch 223/804
# Processing batch 224/804
# Processing batch 225/804
# Processing batch 226/804
# Processing batch 227/804
# Processing batch 228/804
# Processing batch 229/804
# Processing batch 230/804
# Processing batch 231/804
# Processing batch 232/804
# Processing batch 233/804
# Processing batch 234/804
# Processing batch 235/804
# Processing batch 236/804
# Processing batch 237/804
# Processing batch 238/804
# Processing batch 239/804
# Processing batch 240/804
# Processing batch 241/804
# Processing batch 242/804
# Processing batch 243/804
# Processing batch 244/804
# Processing batch 245/804
# Processing batch 246/804
# Processing batch 247/804
# Processing batch 248/804
# Processing batch 249/804
# Processing batch 250/804
# Processing batch 251/804
# Processing batch 252/804
# Processing batch 253/804
# Processing batch 254/804
# Processing batch 255/804
# Processing batch 256/804
# Processing batch 257/804
# Processing batch 258/804
# Processing batch 259/804
# Processing batch 260/804
# Processing batch 261/804
# Processing batch 262/804
# Processing batch 263/804
# Processing batch 264/804
# Processing batch 265/804
# Processing batch 266/804
# Processing batch 267/804
# Processing batch 268/804
# Processing batch 269/804
# Processing batch 270/804
# Processing batch 271/804
# Processing batch 272/804
# Processing batch 273/804
# Processing batch 274/804
# Processing batch 275/804
# Processing batch 276/804
# Processing batch 277/804
# Processing batch 278/804
# Processing batch 279/804
# Processing batch 280/804
# Processing batch 281/804
# Processing batch 282/804
# Processing batch 283/804
# Processing batch 284/804
# Processing batch 285/804
# Processing batch 286/804
# Processing batch 287/804
# Processing batch 288/804
# Processing batch 289/804
# Processing batch 290/804
# Processing batch 291/804
# Processing batch 292/804
# Processing batch 293/804
# Processing batch 294/804
# Processing batch 295/804
# Processing batch 296/804
# Processing batch 297/804
# Processing batch 298/804
# Processing batch 299/804
# Processing batch 300/804
# Processing batch 301/804
# Processing batch 302/804
# Processing batch 303/804
# Processing batch 304/804
# Processing batch 305/804
# Processing batch 306/804
# Processing batch 307/804
# Processing batch 308/804
# Processing batch 309/804
# Processing batch 310/804
# Processing batch 311/804
# Processing batch 312/804
# Processing batch 313/804
# Processing batch 314/804
# Processing batch 315/804
# Processing batch 316/804
# Processing batch 317/804
# Processing batch 318/804
# Processing batch 319/804
# Processing batch 320/804
# Processing batch 321/804
# Processing batch 322/804
# Processing batch 323/804
# Processing batch 324/804
# Processing batch 325/804
# Processing batch 326/804
# Processing batch 327/804
# Processing batch 328/804
# Processing batch 329/804
# Processing batch 330/804
# Processing batch 331/804
# Processing batch 332/804
# Processing batch 333/804
# Processing batch 334/804
# Processing batch 335/804
# Processing batch 336/804
# Processing batch 337/804
# Processing batch 338/804
# Processing batch 339/804
# Processing batch 340/804
# Processing batch 341/804
# Processing batch 342/804
# Processing batch 343/804
# Processing batch 344/804
# Processing batch 345/804
# Processing batch 346/804
# Processing batch 347/804
# Processing batch 348/804
# Processing batch 349/804
# Processing batch 350/804
# Processing batch 351/804
# Processing batch 352/804
# Processing batch 353/804
# Processing batch 354/804
# Processing batch 355/804
# Processing batch 356/804
# Processing batch 357/804
# Processing batch 358/804
# Processing batch 359/804
# Processing batch 360/804
# Processing batch 361/804
# Processing batch 362/804
# Processing batch 363/804
# Processing batch 364/804
# Processing batch 365/804
# Processing batch 366/804
# Processing batch 367/804
# Processing batch 368/804
# Processing batch 369/804
# Processing batch 370/804
# Processing batch 371/804
# Processing batch 372/804
# Processing batch 373/804
# Processing batch 374/804
# Processing batch 375/804
# Processing batch 376/804
# Processing batch 377/804
# Processing batch 378/804
# Processing batch 379/804
# Processing batch 380/804
# Processing batch 381/804
# Processing batch 382/804
# Processing batch 383/804
# Processing batch 384/804
# Processing batch 385/804
# Processing batch 386/804
# Processing batch 387/804
# Processing batch 388/804
# Processing batch 389/804
# Processing batch 390/804
# Processing batch 391/804
# Processing batch 392/804
# Processing batch 393/804
# Processing batch 394/804
# Processing batch 395/804
# Processing batch 396/804
# Processing batch 397/804
# Processing batch 398/804
# Processing batch 399/804
# Processing batch 400/804
# Processing batch 401/804
# Processing batch 402/804
# Processing batch 403/804
# Processing batch 404/804
# Processing batch 405/804
# Processing batch 406/804
# Processing batch 407/804
# Processing batch 408/804
# Processing batch 409/804
# Processing batch 410/804
# Processing batch 411/804
# Processing batch 412/804
# Processing batch 413/804
# Processing batch 414/804
# Processing batch 415/804
# Processing batch 416/804
# Processing batch 417/804
# Processing batch 418/804
# Processing batch 419/804
# Processing batch 420/804
# Processing batch 421/804
# Processing batch 422/804
# Processing batch 423/804
# Processing batch 424/804
# Processing batch 425/804
# Processing batch 426/804
# Processing batch 427/804
# Processing batch 428/804
# Processing batch 429/804
# Processing batch 430/804
# Processing batch 431/804
# Processing batch 432/804
# Processing batch 433/804
# Processing batch 434/804
# Processing batch 435/804
# Processing batch 436/804
# Processing batch 437/804
# Processing batch 438/804
# Processing batch 439/804
# Processing batch 440/804
# Processing batch 441/804
# Processing batch 442/804
# Processing batch 443/804
# Processing batch 444/804
# Processing batch 445/804
# Processing batch 446/804
# Processing batch 447/804
# Processing batch 448/804
# Processing batch 449/804
# Processing batch 450/804
# Processing batch 451/804
# Processing batch 452/804
# Processing batch 453/804
# Processing batch 454/804
# Processing batch 455/804
# Processing batch 456/804
# Processing batch 457/804
# Processing batch 458/804
# Processing batch 459/804
# Processing batch 460/804
# Processing batch 461/804
# Processing batch 462/804
# Processing batch 463/804
# Processing batch 464/804
# Processing batch 465/804
# Processing batch 466/804
# Processing batch 467/804
# Processing batch 468/804
# Processing batch 469/804
# Processing batch 470/804
# Processing batch 471/804
# Processing batch 472/804
# Processing batch 473/804
# Processing batch 474/804
# Processing batch 475/804
# Processing batch 476/804
# Processing batch 477/804
# Processing batch 478/804
# Processing batch 479/804
# Processing batch 480/804
# Processing batch 481/804
# Processing batch 482/804
# Processing batch 483/804
# Processing batch 484/804
# Processing batch 485/804
# Processing batch 486/804
# Processing batch 487/804
# Processing batch 488/804
# Processing batch 489/804
# Processing batch 490/804
# Processing batch 491/804
# Processing batch 492/804
# Processing batch 493/804
# Processing batch 494/804
# Processing batch 495/804
# Processing batch 496/804
# Processing batch 497/804
# Processing batch 498/804
# Processing batch 499/804
# Processing batch 500/804
# Processing batch 501/804
# Processing batch 502/804
# Processing batch 503/804
# Processing batch 504/804
# Processing batch 505/804
# Processing batch 506/804
# Processing batch 507/804
# Processing batch 508/804
# Processing batch 509/804
# Processing batch 510/804
# Processing batch 511/804
# Processing batch 512/804
# Processing batch 513/804
# Processing batch 514/804
# Processing batch 515/804
# Processing batch 516/804
# Processing batch 517/804
# Processing batch 518/804
# Processing batch 519/804
# Processing batch 520/804
# Processing batch 521/804
# Processing batch 522/804
# Processing batch 523/804
# Processing batch 524/804
# Processing batch 525/804
# Processing batch 526/804
# Processing batch 527/804
# Processing batch 528/804
# Processing batch 529/804
# Processing batch 530/804
# Processing batch 531/804
# Processing batch 532/804
# Processing batch 533/804
# Processing batch 534/804
# Processing batch 535/804
# Processing batch 536/804
# Processing batch 537/804
# Processing batch 538/804
# Processing batch 539/804
# Processing batch 540/804
# Processing batch 541/804
# Processing batch 542/804
# Processing batch 543/804
# Processing batch 544/804
# Processing batch 545/804
# Processing batch 546/804
# Processing batch 547/804
# Processing batch 548/804
# Processing batch 549/804
# Processing batch 550/804
# Processing batch 551/804
# Processing batch 552/804
# Processing batch 553/804
# Processing batch 554/804
# Processing batch 555/804
# Processing batch 556/804
# Processing batch 557/804
# Processing batch 558/804
# Processing batch 559/804
# Processing batch 560/804
# Processing batch 561/804
# Processing batch 562/804
# Processing batch 563/804
# Processing batch 564/804
# Processing batch 565/804
# Processing batch 566/804
# Processing batch 567/804
# Processing batch 568/804
# Processing batch 569/804
# Processing batch 570/804
# Processing batch 571/804
# Processing batch 572/804
# Processing batch 573/804
# Processing batch 574/804
# Processing batch 575/804
# Processing batch 576/804
# Processing batch 577/804
# Processing batch 578/804
# Processing batch 579/804
# Processing batch 580/804
# Processing batch 581/804
# Processing batch 582/804
# Processing batch 583/804
# Processing batch 584/804
# Processing batch 585/804
# Processing batch 586/804
# Processing batch 587/804
# Processing batch 588/804
# Processing batch 589/804
# Processing batch 590/804
# Processing batch 591/804
# Processing batch 592/804
# Processing batch 593/804
# Processing batch 594/804
# Processing batch 595/804
# Processing batch 596/804
# Processing batch 597/804
# Processing batch 598/804
# Processing batch 599/804
# Processing batch 600/804
# Processing batch 601/804
# Processing batch 602/804
# Processing batch 603/804
# Processing batch 604/804
# Processing batch 605/804
# Processing batch 606/804
# Processing batch 607/804
# Processing batch 608/804
# Processing batch 609/804
# Processing batch 610/804
# Processing batch 611/804
# Processing batch 612/804
# Processing batch 613/804
# Processing batch 614/804
# Processing batch 615/804
# Processing batch 616/804
# Processing batch 617/804
# Processing batch 618/804
# Processing batch 619/804
# Processing batch 620/804
# Processing batch 621/804
# Processing batch 622/804
# Processing batch 623/804
# Processing batch 624/804
# Processing batch 625/804
# Processing batch 626/804
# Processing batch 627/804
# Processing batch 628/804
# Processing batch 629/804
# Processing batch 630/804
# Processing batch 631/804
# Processing batch 632/804
# Processing batch 633/804
# Processing batch 634/804
# Processing batch 635/804
# Processing batch 636/804
# Processing batch 637/804
# Processing batch 638/804
# Processing batch 639/804
# Processing batch 640/804
# Processing batch 641/804
# Processing batch 642/804
# Processing batch 643/804
# Processing batch 644/804
# Processing batch 645/804
# Processing batch 646/804
# Processing batch 647/804
# Processing batch 648/804
# Processing batch 649/804
# Processing batch 650/804
# Processing batch 651/804
# Processing batch 652/804
# Processing batch 653/804
# Processing batch 654/804
# Processing batch 655/804
# Processing batch 656/804
# Processing batch 657/804
# Processing batch 658/804
# Processing batch 659/804
# Processing batch 660/804
# Processing batch 661/804
# Processing batch 662/804
# Processing batch 663/804
# Processing batch 664/804
# Processing batch 665/804
# Processing batch 666/804
# Processing batch 667/804
# Processing batch 668/804
# Processing batch 669/804
# Processing batch 670/804
# Processing batch 671/804
# Processing batch 672/804
# Processing batch 673/804
# Processing batch 674/804
# Processing batch 675/804
# Processing batch 676/804
# Processing batch 677/804
# Processing batch 678/804
# Processing batch 679/804
# Processing batch 680/804
# Processing batch 681/804
# Processing batch 682/804
# Processing batch 683/804
# Processing batch 684/804
# Processing batch 685/804
# Processing batch 686/804
# Processing batch 687/804
# Processing batch 688/804
# Processing batch 689/804
# Processing batch 690/804
# Processing batch 691/804
# Processing batch 692/804
# Processing batch 693/804
# Processing batch 694/804
# Processing batch 695/804
# Processing batch 696/804
# Processing batch 697/804
# Processing batch 698/804
# Processing batch 699/804
# Processing batch 700/804
# Processing batch 701/804
# Processing batch 702/804
# Processing batch 703/804
# Processing batch 704/804
# Processing batch 705/804
# Processing batch 706/804
# Processing batch 707/804
# Processing batch 708/804
# Processing batch 709/804
# Processing batch 710/804
# Processing batch 711/804
# Processing batch 712/804
# Processing batch 713/804
# Processing batch 714/804
# Processing batch 715/804
# Processing batch 716/804
# Processing batch 717/804
# Processing batch 718/804
# Processing batch 719/804
# Processing batch 720/804
# Processing batch 721/804
# Processing batch 722/804
# Processing batch 723/804
# Processing batch 724/804
# Processing batch 725/804
# Processing batch 726/804
# Processing batch 727/804
# Processing batch 728/804
# Processing batch 729/804
# Processing batch 730/804
# Processing batch 731/804
# Processing batch 732/804
# Processing batch 733/804
# Processing batch 734/804
# Processing batch 735/804
# Processing batch 736/804
# Processing batch 737/804
# Processing batch 738/804
# Processing batch 739/804
# Processing batch 740/804
# Processing batch 741/804
# Processing batch 742/804
# Processing batch 743/804
# Processing batch 744/804
# Processing batch 745/804
# Processing batch 746/804
# Processing batch 747/804
# Processing batch 748/804
# Processing batch 749/804
# Processing batch 750/804
# Processing batch 751/804
# Processing batch 752/804
# Processing batch 753/804
# Processing batch 754/804
# Processing batch 755/804
# Processing batch 756/804
# Processing batch 757/804
# Processing batch 758/804
# Processing batch 759/804
# Processing batch 760/804
# Processing batch 761/804
# Processing batch 762/804
# Processing batch 763/804
# Processing batch 764/804
# Processing batch 765/804
# Processing batch 766/804
# Processing batch 767/804
# Processing batch 768/804
# Processing batch 769/804
# Processing batch 770/804
# Processing batch 771/804
# Processing batch 772/804
# Processing batch 773/804
# Processing batch 774/804
# Processing batch 775/804
# Processing batch 776/804
# Processing batch 777/804
# Processing batch 778/804
# Processing batch 779/804
# Processing batch 780/804
# Processing batch 781/804
# Processing batch 782/804
# Processing batch 783/804
# Processing batch 784/804
# Processing batch 785/804
# Processing batch 786/804
# Processing batch 787/804
# Processing batch 788/804
# Processing batch 789/804
# Processing batch 790/804
# Processing batch 791/804
# Processing batch 792/804
# Processing batch 793/804
# Processing batch 794/804
# Processing batch 795/804
# Processing batch 796/804
# Processing batch 797/804
# Processing batch 798/804
# Processing batch 799/804
# Processing batch 800/804
# Processing batch 801/804
# Processing batch 802/804
# Processing batch 803/804
# Processing batch 804/804

# %%
# Load all numpy files
features_list = [np.load(features_file) for features_file in sorted(features_path.glob("*.npy"))]

# Concatenate the features and store in a merged file
features = np.concatenate(features_list)
np.save(features_path / "features.npy", features)

# Load all the image IDs
image_ids = pd.concat([pd.read_csv(ids_file) for ids_file in sorted(features_path.glob("*.csv"))])
image_ids.to_csv(features_path / "image_ids.csv", index=False)

# %% [markdown]
# ## Load Features

# %%
# Load the image IDs
image_ids = pd.read_csv(features_path / 'image_ids.csv')
image_ids = list(image_ids['image_id'])

# Load the features vectors
image_features = np.load(features_path / 'features.npy')

# Convert features to Tensors: Float32 on CPU and Float16 on GPU
if device == "cpu":
    image_features = torch.from_numpy(image_features).float().to(device)
else:
    image_features = torch.from_numpy(image_features).to(device)

# Print some statistics
print(f"Images loaded: {len(image_ids)}")
# Out:
# Images loaded: 12852

# %% [markdown]
# ## Search Images Based on a Text Query

# %%
def encode_search_query(search_query):
    with torch.no_grad():
        # Encode and normalize the search query using CLIP
        text_encoded = model.encode_text(clip.tokenize(search_query).to(device))
        text_encoded /= text_encoded.norm(dim=-1, keepdim=True)

    # Retrieve the feature vector
    return text_encoded

def find_best_matches(text_features, image_features, image_ids, results_count=3):
  # Compute the similarity between the search query and each image using the Cosine similarity
  similarities = (image_features @ text_features.T).squeeze(1)

  # Sort the images by their similarity score
  best_image_idx = (-similarities).argsort()

  # Return the image IDs of the best matches
  return [image_ids[i] for i in best_image_idx[:results_count]]

def search(search_query, image_features, image_ids, results_count=3):
  # Encode the search query
  text_features = encode_search_query(search_query)

  # Find the best matches
  return find_best_matches(text_features, image_features, image_ids, results_count)

#
# Search for images and visualize the results
#
search_queries = ['T shirt', 
                  'Footwear', 
                  'Jacket', 
                  'Hat',
                  'skirt',
                  'pants',
                  'tops']
n_results_per_query = 3
 
fig, ax = plt.subplots(len(search_queries), n_results_per_query + 1, figsize=(15, 10))    
for i, search_query in enumerate(search_queries):
    result_image_ids = search(search_query, image_features, image_ids, n_results_per_query)
    
    ax[i, 0].text(0.0, 0.5, search_query)
    ax[i, 0].axis('off')
    for j, image_id in enumerate(result_image_ids):
        image = Image.open(f'{images_path}/{image_id}.jpg')
        ax[i, j+1].imshow(image)
        ax[i, j+1].axis('off')
